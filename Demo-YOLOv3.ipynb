# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone 'https://github.com/aakashvardhan/YoloV3.git'
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 404, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (233/233), done.
# remote: Total 404 (delta 19), reused 238 (delta 13), pack-reused 156
# Receiving objects: 100% (404/404), 38.31 MiB | 15.33 MiB/s, done.
# Resolving deltas: 100% (26/26), done.

# %%
import sys
sys.path.append('/content/YoloV3')
sys.path.append('/content/YoloV3/weights')

# %%
# %cd /content/YoloV3
# Out:
# /content/YoloV3

# %%
# !mkdir weights

# %%
# !cp /content/drive/MyDrive/ERA\ v2/s12-yolov3/yolov3-spp-ultralytics.pt  /content/YoloV3/weights

# %%
drive.flush_and_unmount()

# %%
# !python train.py --data /content/YoloV3/data/animal.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 3 --nosave
# Out:
# Namespace(epochs=3, batch_size=10, accumulate=4, cfg='cfg/yolov3-custom.cfg', data='/content/YoloV3/data/animal.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# 2024-04-18 13:48:33.715208: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-18 13:48:33.715274: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...
