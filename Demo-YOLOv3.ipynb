# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone 'https://github.com/aakashvardhan/YoloV3.git'
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 389, done.
# remote: Counting objects: 100% (233/233), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 389 (delta 10), reused 225 (delta 7), pack-reused 156
# Receiving objects: 100% (389/389), 38.30 MiB | 25.96 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
import sys
sys.path.append('/content/YoloV3')
sys.path.append('/content/YoloV3/weights')

# %%
# %cd /content/YoloV3
# Out:
# /content/YoloV3

# %%
# !mkdir weights

# %%
# !cp /content/drive/MyDrive/ERA\ v2/s12-yolov3/yolov3-spp-ultralytics.pt  /content/YoloV3/weights

# %%
drive.flush_and_unmount()

# %%
# !python train.py --data /content/YoloV3/data/animal.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 3 --nosave
# Out:
# Namespace(epochs=3, batch_size=10, accumulate=4, cfg='cfg/yolov3-custom.cfg', data='/content/YoloV3/data/animal.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# 2024-04-18 13:24:56.640110: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-18 13:24:56.640174: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-18 13:24:56.641739: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-18 13:24:57.973962: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.29795e+07 parameters, 6.29795e+07 gradients
# Caching labels (100 found, 0 missing, 0 empty, 0 duplicate, for 100 images): 100% 100/100 [00:00<00:00, 4989.42it/s]
# Caching images (0.1GB): 100% 100/100 [00:02<00:00, 35.83it/s]
# Reading image shapes: 100% 100/100 [00:00<00:00, 4772.00it/s]
# Caching labels (100 found, 0 missing, 0 empty, 0 duplicate, for 100 images): 100% 100/100 [00:00<00:00, 3652.18it/s]
# Caching images (0.1GB): 100% 100/100 [00:02<00:00, 33.60it/s]
# Image sizes 512 - 512 train, 512 test
# Using 2 dataloader workers
# Starting training for 3 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0% 0/10 [00:01<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/YoloV3/train.py", line 430, in <module>
#     train()  # train normally
#   File "/content/YoloV3/train.py", line 263, in train
#     pred = model(imgs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/YoloV3/models.py", line 235, in forward
#     return self.forward_once(x)
#   File "/content/YoloV3/models.py", line 287, in forward_once
#     yolo_out.append(module(x, out))
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/YoloV3/models.py", line 188, in forward
#     p = p.view(bs, self.na, self.no, self.ny, self.nx).permute(0, 1, 3, 4, 2).contiguous()  # prediction
# RuntimeError: shape '[10, 3, 60, 16, 16]' is invalid for input of size 652800
