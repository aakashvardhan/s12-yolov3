# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone 'https://github.com/aakashvardhan/YoloV3.git'
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 778, done.
# remote: Counting objects: 100% (622/622), done.
# remote: Compressing objects: 100% (486/486), done.
# remote: Total 778 (delta 135), reused 612 (delta 130), pack-reused 156
# Receiving objects: 100% (778/778), 70.82 MiB | 29.22 MiB/s, done.
# Resolving deltas: 100% (142/142), done.

# %%
import sys
sys.path.append('/content/YoloV3')
sys.path.append('/content/YoloV3/weights')
sys.path.append('/content/YoloV3/utils')
sys.path.append('/content/YoloV3/cfg')
sys.path.append('/content/YoloV3/customdata')

# %%
# %cd /content/YoloV3
# Out:
# /content/YoloV3

# %%
# !mkdir weights

# %%
# !cp /content/drive/MyDrive/ERA\ v2/s12-yolov3/YoloV3/weights/yolov3-spp-ultralytics.pt  /content/YoloV3/weights

# %%
drive.flush_and_unmount()

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
# !CUDA_LAUNCH_BLOCKING=1 python /content/YoloV3/train.py --data /content/YoloV3/data/customdata/custom.data --batch 16 --cache --cfg /content/YoloV3/cfg/yolov3-custom.cfg --epochs 50 --device 0  --nosave
# Out:
# Namespace(epochs=50, batch_size=16, accumulate=4, cfg='/content/YoloV3/cfg/yolov3-custom.cfg', data='/content/YoloV3/data/customdata/custom.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='./weights/yolov3-spp-ultralytics.pt', name='', device='0', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# 2024-04-22 15:15:16.905589: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-22 15:15:16.905634: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python /content/YoloV3/test.py --data /content/YoloV3/data/customdata/custom.data --weights /content/YoloV3/weights/last.pt --img-size 512 --augment
# Out:
# Namespace(cfg='./cfg/yolov3-custom.cfg', data='/content/YoloV3/data/customdata/custom.data', weights='/content/YoloV3/weights/last.pt', batch_size=16, img_size=512, conf_thres=0.001, iou_thres=0.6, save_json=False, task='test', device='', single_cls=False, augment=True)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Fusing layers...
# Model Summary: 152 layers, 6.25465e+07 parameters, 6.25465e+07 gradients
# Caching labels (99 found, 0 missing, 1 empty, 0 duplicate, for 100 images): 100% 100/100 [00:00<00:00, 7370.07it/s]
# ...

# %%
# !python /content/YoloV3/detect.py --conf-thres 0.1 --iou-thres 0.4 --augment
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='data/customdata/images', output='output', img_size=512, conf_thres=0.1, iou_thres=0.4, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=True)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/100 data/customdata/images/image_1.jpg: 320x512 1 tigers, Done. (0.236s)
# image 2/100 data/customdata/images/image_10.jpg: 512x448 1 tigers, Done. (0.237s)
# ...

# %%
# !nvidia-smi
# Out:
# Mon Apr 22 15:25:56 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   75C    P0              47W /  70W |      0MiB / 15360MiB |     45%      Default |
# |                                         |                      |                  N/A |
# ...
