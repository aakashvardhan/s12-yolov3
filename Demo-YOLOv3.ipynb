# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone 'https://github.com/aakashvardhan/YoloV3.git'
# Out:
# Cloning into 'YoloV3'...
# remote: Enumerating objects: 565, done.
# remote: Counting objects: 100% (409/409), done.
# remote: Compressing objects: 100% (325/325), done.
# remote: Total 565 (delta 119), reused 368 (delta 81), pack-reused 156
# Receiving objects: 100% (565/565), 38.37 MiB | 19.83 MiB/s, done.
# Resolving deltas: 100% (126/126), done.

# %%
import sys
sys.path.append('/content/YoloV3')
sys.path.append('/content/YoloV3/weights')
sys.path.append('/content/YoloV3/utils')
sys.path.append('/content/YoloV3/cfg')
sys.path.append('/content/YoloV3/customdata')

# %%
# %cd /content/YoloV3
# Out:
# /content/YoloV3

# %%
# !mkdir weights

# %%
# !cp /content/drive/MyDrive/ERA\ v2/s12-yolov3/YoloV3/weights/yolov3-spp-ultralytics.pt  /content/YoloV3/weights

# %%
drive.flush_and_unmount()

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
# !CUDA_LAUNCH_BLOCKING=1 python /content/YoloV3/train.py --data /content/YoloV3/data/customdata/custom.data --batch 16 --cache --cfg /content/YoloV3/cfg/yolov3-custom.cfg --epochs 50 --device 0  --nosave
# Out:
# Namespace(epochs=50, batch_size=16, accumulate=4, cfg='/content/YoloV3/cfg/yolov3-custom.cfg', data='/content/YoloV3/data/customdata/custom.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='./weights/yolov3-spp-ultralytics.pt', name='', device='0', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# 2024-04-20 06:31:39.896999: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-20 06:31:39.897044: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-20 06:31:39.898380: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-20 06:31:40.987645: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# WARNING: smart bias initialization failure.
# Model Summary: 225 layers, 6.28641e+07 parameters, 6.28641e+07 gradients
# Caching labels (100 found, 0 missing, 0 empty, 0 duplicate, for 100 images): 100% 100/100 [00:00<00:00, 5531.34it/s]
# Caching images (0.1GB): 100% 100/100 [00:01<00:00, 64.79it/s]
# Caching labels (100 found, 0 missing, 0 empty, 0 duplicate, for 100 images): 100% 100/100 [00:00<00:00, 8005.31it/s]
# Caching images (0.1GB): 100% 100/100 [00:02<00:00, 45.84it/s]
# Image sizes 512 - 512 train, 512 test
# Using 8 dataloader workers
# Starting training for 50 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0% 0/7 [00:00<?, ?it/s]/content/YoloV3/utils/utils.py:375: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   lcls, lbox, lobj = ft([0]), ft([0]), ft([0])
# /usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:440: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   warnings.warn(
#       0/49     11.8G      8.15       162      56.7       226        47       512:  14% 1/7 [00:08<00:52,  8.79s/it]/usr/local/lib/python3.10/dist-packages/torch/cuda/memory.py:440: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   warnings.warn(
#       0/49     12.4G      7.76      88.5      54.5       151        11       512: 100% 7/7 [00:15<00:00,  2.22s/it]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#                Class    Images   Targets         P         R   mAP@0.5        F1:   0% 0/7 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                Class    Images   Targets         P         R   mAP@0.5        F1: 100% 7/7 [00